# %% [markdown]
# # ERCOT Tier-2 Validation Notebook
# Reference skeleton for March 2026 UCMS/SCFL operator suite.
#
# This notebook will:
# - Load public ERCOT signals
# - Apply operator suite metrics
# - Produce Tier-2 validation outputs

# %%
import pandas as pd
import numpy as np
from operators.delta_g import DeltaG
from operators.cdi import CDI
from operators.fidelity_gradient import FidelityGradient
from operators.ripple import Ripple
from operators.substrate import Substrate
from ercot_pilot.data_preprocessing import load_public_signals
from ercot_pilot.tier2_metrics import compute_cdi_pearson_r, compute_false_positive_rate

# %% [markdown]
# ## Placeholder: Load sample data

# %%
df = load_public_signals('data/ercot_public_signals_sample.csv')
df
